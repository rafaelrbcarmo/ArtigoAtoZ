# %%
# -*- coding: utf-8 -*-
"""
Script FINAL (Versão 4.4 - Filtragem de Sinopse por Tamanho): Análise de Frequência de Palavras em Sinopses de Filmes de Terror (1980-1989).

Este script coleta 200 sinopses de filmes do gênero terror, lançados entre 1980 e 1989,
focando apenas nos critérios de ano e gênero, sem considerar popularidade.
Implementa uma filtragem heurística de sinopses muito longas (provavelmente reviews ou long plots)
para tentar obter apenas o resumo do enredo.
Utiliza a biblioteca Cinemagoer (IMDbPY) para a coleta e SpaCy para pré-processamento.
A saída durante a coleta é concisa, e o resultado final exibe as 100 palavras mais frequentes.
"""

import imdb
import spacy
from collections import Counter
import pandas as pd
import time
import random

# --- Carregar o modelo SpaCy de inglês ---
try:
    nlp = spacy.load("en_core_web_sm")
    print("Modelo SpaCy 'en_core_web_sm' carregado com sucesso.")
except OSError:
    print("\nERRO CRÍTICO: Modelo SpaCy 'en_core_web_sm' não encontrado ou não carregado.")
    print("Por favor, certifique-se de que você executou o comando:")
    print("  python -m spacy download en_core_web_sm")
    print("no seu Anaconda Prompt/Terminal (com o ambiente 'terror_nlp' ativo) ANTES de executar este script.")
    exit()

# --- Configurações Finais do Projeto ---
ia = imdb.IMDb()
ANOS_INICIO = 1980
ANOS_FIM = 1989
GENERO_DESEJADO = 'horror'
QUANTIDADE_FILMES = 200
TOP_TERMOS_SINOPSE = 100

IMDB_BASE_URL = "https://www.imdb.com/title/tt"

# --- Novo Filtro para Sinopses ---
MAX_WORDS_IN_PLOT = 500 # Limite heurístico de palavras para considerar uma sinopse válida
                        # Sinopses normais raramente excedem 500 palavras. Avaliações podem ter milhares.

print(f"Iniciando a coleta de {QUANTIDADE_FILMES} filmes do gênero '{GENERO_DESEJADO}' lançados entre {ANOS_INICIO} e {ANOS_FIM} (filtrando sinopses muito longas)...")

filmes_para_processar = []
filmes_ids_coletados = set()

print("\n--- Coleta de Filmes: Aguarde, este processo pode levar alguns minutos... ---")
for year in range(ANOS_INICIO, ANOS_FIM + 1):
    if len(filmes_para_processar) >= QUANTIDADE_FILMES:
        break

    try:
        search_results = ia.search_movie(f'horror {year}') 
        
        for movie in search_results:
            if len(filmes_para_processar) >= QUANTIDADE_FILMES:
                break
            
            try:
                ia.update(movie, ['plot', 'main'])
                time.sleep(0.1 + (random.random() * 0.1))

                if movie.get('year') == year:
                    genres = [g.lower() for g in movie.get('genres', [])]
                    if GENERO_DESEJADO in genres:
                        plot_summary_raw = movie.get('plot', movie.get('plots', ['N/A']))
                        if isinstance(plot_summary_raw, list):
                            plot_summary_temp = " ".join(plot_summary_raw)
                        else:
                            plot_summary_temp = plot_summary_raw
                        
                        # --- Aplicação do Filtro de Tamanho ---
                        if plot_summary_temp and plot_summary_temp.strip() != '':
                            # Tokeniza temporariamente para contar palavras
                            doc_temp = nlp(plot_summary_temp)
                            num_words = len([token for token in doc_temp if token.is_alpha]) # Conta apenas palavras alfabéticas
                            
                            if num_words > MAX_WORDS_IN_PLOT:
                                # print(f"  Sinopse muito longa para '{movie.get('title')}' ({num_words} palavras). Descartando ou truncando.")
                                # Podemos descartar ou tentar pegar só um trecho inicial
                                # Por enquanto, vamos descartar para ter sinopses mais limpas
                                plot_summary = None # Descartar se for muito longa
                            else:
                                plot_summary = plot_summary_temp # Aceitar se estiver dentro do limite
                        else:
                            plot_summary = None # Sinopse vazia ou inválida
                        # --- Fim do Filtro de Tamanho ---

                        if plot_summary and movie.movieID not in filmes_ids_coletados:
                            filmes_para_processar.append({
                                'title': movie.get('title'),
                                'year': movie.get('year'),
                                'genres': movie.get('genres'),
                                'plot': plot_summary,
                                'imdb_link': f"{IMDB_BASE_URL}{movie.movieID}"
                            })
                            filmes_ids_coletados.add(movie.movieID)
                            print(f"Coletado ({len(filmes_para_processar)}/{QUANTIDADE_FILMES}): {movie.get('title')} ({movie.get('year')}) - {IMDB_BASE_URL}{movie.movieID}")
            except Exception as e:
                pass
    except Exception as e:
        pass

print(f"\n--- Coleta de Filmes Concluída: {len(filmes_para_processar)} de {QUANTIDADE_FILMES} filmes coletados. ---")

if not filmes_para_processar:
    print("Nenhum filme foi encontrado com os critérios especificados. Verifique as configurações ou tente novamente.")
else:
    textos_sinopses = [f['plot'] for f in filmes_para_processar if f['plot'] is not None] # Filtra sinopses None
    texto_completo_sinopses = " ".join(textos_sinopses)

    print("\n--- Análise das Sinopses ---")
    print("Iniciando pré-processamento das sinopses com SpaCy...")
    doc_sinopses = nlp(texto_completo_sinopses.lower())

    palavras_sinopses_filtradas = [
        token.text for token in doc_sinopses
        if not token.is_stop and not token.is_punct and token.is_alpha and len(token.text) > 1
    ]

    print("Calculando frequência das palavras nas sinopses...")
    frequencia_palavras_sinopses = Counter(palavras_sinopses_filtradas)
    top_termos_sinopses = frequencia_palavras_sinopses.most_common(TOP_TERMOS_SINOPSE)

    print(f"\n--- {TOP_TERMOS_SINOPSE} Palavras Mais Frequentes nas Sinopses ---")
    for palavra, frequencia in top_termos_sinopses:
        print(f"'{palavra}': {frequencia}")

print("\nProcesso concluído!")
# Out:
# Modelo SpaCy 'en_core_web_sm' carregado com sucesso.
# Iniciando a coleta de 200 filmes do gênero 'horror' lançados entre 1980 e 1989 (filtrando sinopses muito longas)...
#
# --- Coleta de Filmes: Aguarde, este processo pode levar alguns minutos... ---
# Coletado (1/200): Hammer House of Horror (1980) - https://www.imdb.com/title/tt0080231
# Coletado (2/200): Inferno (1980) - https://www.imdb.com/title/tt0080923
# Coletado (3/200): Chamber 13 - Tales of Horror (1980) - https://www.imdb.com/title/tt9426590
# Coletado (4/200): Without Warning (1980) - https://www.imdb.com/title/tt0081764
# Coletado (5/200): Alligator (1980) - https://www.imdb.com/title/tt0080354
# Coletado (6/200): The Godsend (1980) - https://www.imdb.com/title/tt0080802
# Coletado (7/200): Blood Beach (1980) - https://www.imdb.com/title/tt0082083
# Coletado (8/200): White Cannibal Queen (1980) - https://www.imdb.com/title/tt0078936
# Coletado (9/200): Macabre (1980) - https://www.imdb.com/title/tt0080764
# Coletado (10/200): Monstroid (1980) - https://www.imdb.com/title/tt0079573
# Coletado (11/200): Count Gregore's Horror Theater (1980) - https://www.imdb.com/title/tt12580136
# Coletado (12/200): Don't Answer the Phone! (1980) - https://www.imdb.com/title/tt0080645
# Coletado (13/200): The Late, Great Horror Show (1980) - https://www.imdb.com/title/tt9332918
# Coletado (14/200): Night of Horror (1981) - https://www.imdb.com/title/tt0202496
# Coletado (15/200): Cannibal Ferox (1981) - https://www.imdb.com/title/tt0082700
# Coletado (16/200): The Howling (1981) - https://www.imdb.com/title/tt0082533
# Coletado (17/200): The Evil Dead (1981) - https://www.imdb.com/title/tt0083907
# Coletado (18/200): Halloween II (1981) - https://www.imdb.com/title/tt0082495
# Coletado (19/200): Burial Ground (1981) - https://www.imdb.com/title/tt0081248
# Coletado (20/200): Inseminoid (1981) - https://www.imdb.com/title/tt0084090
# Coletado (21/200): The Funhouse (1981) - https://www.imdb.com/title/tt0082427
# Coletado (22/200): Count Zappula's Horror House (1981) - https://www.imdb.com/title/tt11412340
# Coletado (23/200): The Being (1981) - https://www.imdb.com/title/tt0085224
# Coletado (24/200): Dr. Ochanoko's Horror Theater (1981) - https://www.imdb.com/title/tt29431439
# Coletado (25/200): Galaxy of Terror (1981) - https://www.imdb.com/title/tt0082431
# Coletado (26/200): Monster of Frankenstein (1981) - https://www.imdb.com/title/tt0270954
# Coletado (27/200): Comedy of Horrors (1981) - https://www.imdb.com/title/tt0898278
# Coletado (28/200): Night of Destiny (1981) - https://www.imdb.com/title/tt0295468
# Coletado (29/200): The Sunday Horrors (1981) - https://www.imdb.com/title/tt10218634
# Coletado (30/200): The Last Horror Film (1982) - https://www.imdb.com/title/tt0087592
# Coletado (31/200): Invaders of the Lost Gold (1982) - https://www.imdb.com/title/tt0123915
# Coletado (32/200): Honeymoon Horror (1982) - https://www.imdb.com/title/tt0126948
# Coletado (33/200): The Loch Ness Horror (1982) - https://www.imdb.com/title/tt0082669
# Coletado (34/200): Centipede Horror (1982) - https://www.imdb.com/title/tt0096467
# Coletado (35/200): Creepshow (1982) - https://www.imdb.com/title/tt0083767
# Coletado (36/200): Visiting Hours (1982) - https://www.imdb.com/title/tt0083296
# Coletado (37/200): Forbidden World (1982) - https://www.imdb.com/title/tt0083959
# Coletado (38/200): Wacko (1982) - https://www.imdb.com/title/tt0083310
# Coletado (39/200): Mongrel (1982) - https://www.imdb.com/title/tt0084348
# Coletado (40/200): The Vincent Price Gothic Horrors (1982) - https://www.imdb.com/title/tt12073982
# Coletado (41/200): The Horror of It All (1983) - https://www.imdb.com/title/tt0162992
# Coletado (42/200): The Final Terror (1983) - https://www.imdb.com/title/tt0082379
# Coletado (43/200): Frightmare (1983) - https://www.imdb.com/title/tt0083973
# Coletado (44/200): Mountaintop Motel Massacre (1983) - https://www.imdb.com/title/tt0091560
# Coletado (45/200): Children of the Corn (1984) - https://www.imdb.com/title/tt0087050
# Coletado (46/200): The Toxic Avenger (1984) - https://www.imdb.com/title/tt0090190
# Coletado (47/200): Horror Heaven (1984) - https://www.imdb.com/title/tt0269337
# Coletado (48/200): Night of the Comet (1984) - https://www.imdb.com/title/tt0087799
# Coletado (49/200): Horror Vacui (1984) - https://www.imdb.com/title/tt0087424
# Coletado (50/200): Silent Night, Deadly Night (1984) - https://www.imdb.com/title/tt0088117
# Coletado (51/200): Blood Suckers from Outer Space (1984) - https://www.imdb.com/title/tt0086980
# Coletado (52/200): Rocktober Blood (1984) - https://www.imdb.com/title/tt0176097
# Coletado (53/200): Monster Dog (1984) - https://www.imdb.com/title/tt0087616
# Coletado (54/200): The Just Right for Late Night Horror Show (1984) - https://www.imdb.com/title/tt9332932
# Coletado (55/200): Saturday Horror Theater (1984) - https://www.imdb.com/title/tt12580146
# Coletado (56/200): Horror House on Highway Five (1985) - https://www.imdb.com/title/tt0089299
# Coletado (57/200): Howling II: ... Your Sister Is a Werewolf (1985) - https://www.imdb.com/title/tt0089308
# Coletado (58/200): Fright Night (1985) - https://www.imdb.com/title/tt0089175
# Coletado (59/200): Reel Horror (1985) - https://www.imdb.com/title/tt0089894
# Coletado (60/200): Horror Theater (1985) - https://www.imdb.com/title/tt27369936
# Coletado (61/200): House (1985) - https://www.imdb.com/title/tt0091223
# Coletado (62/200): The Best of All Time Horror Classics (1985) - https://www.imdb.com/title/tt2177739
# Coletado (63/200): The Deadly Ernest Horror Show (1985) - https://www.imdb.com/title/tt2544188
# Coletado (64/200): Pequeña historia de horror (1985) - https://www.imdb.com/title/tt0434274
# Coletado (65/200): Tenderloin (1985) - https://www.imdb.com/title/tt0495117
# Coletado (66/200): Miami Golem (1985) - https://www.imdb.com/title/tt0093533
# Coletado (67/200): Dr. Evil's Horror Theatre (1985) - https://www.imdb.com/title/tt13968168
# Coletado (68/200): The Rocky Horror Show (1985) - https://www.imdb.com/title/tt0409231
# Coletado (69/200): Little Shop of Horrors (1986) - https://www.imdb.com/title/tt0091419
# Coletado (70/200): Poltergeist II: The Other Side (1986) - https://www.imdb.com/title/tt0091778
# Coletado (71/200): Chopping Mall (1986) - https://www.imdb.com/title/tt0090837
# Coletado (72/200): Horrible Horror (1986) - https://www.imdb.com/title/tt0134729
# Coletado (73/200): April Fool's Day (1986) - https://www.imdb.com/title/tt0090655
# Coletado (74/200): Deadly Friend (1986) - https://www.imdb.com/title/tt0090917
# Coletado (75/200): Crawlspace (1986) - https://www.imdb.com/title/tt0090881
# Coletado (76/200): Trick or Treat (1986) - https://www.imdb.com/title/tt0092112
# Coletado (77/200): Festival of Fear (1986) - https://www.imdb.com/title/tt0330341
# Coletado (78/200): You'll Die at Midnight (1986) - https://www.imdb.com/title/tt0091553
# Coletado (79/200): Scream Greats, Volume I: Tom Savini (1986) - https://www.imdb.com/title/tt0241929
# Coletado (80/200): Daikanyama Wonderland Horror (1986) - https://www.imdb.com/title/tt29439491
# Coletado (81/200): Girls School Screamers (1986) - https://www.imdb.com/title/tt0091118
# Coletado (82/200): Torment (1986) - https://www.imdb.com/title/tt0092100
# Coletado (83/200): A Judgment in Stone (1986) - https://www.imdb.com/title/tt0091305
# Coletado (84/200): The Horror and Mystery of the Succubus (1986) - https://www.imdb.com/title/tt0293245
# Coletado (85/200): Doorways to Horror (1986) - https://www.imdb.com/title/tt17276634
# Coletado (86/200): The Host: Tom Leahy, TV Horror Host Pioneer (1986) - https://www.imdb.com/title/tt8827262
# Coletado (87/200): Return to Horror High (1987) - https://www.imdb.com/title/tt0093854
# Coletado (88/200): Street Trash (1987) - https://www.imdb.com/title/tt0094057
# Coletado (89/200): Horror Brunch!!! (1987) - https://www.imdb.com/title/tt0379315
# Coletado (90/200): Howling III (1987) - https://www.imdb.com/title/tt0093227
# Coletado (91/200): Slaughterhouse Rock (1987) - https://www.imdb.com/title/tt0096117
# Coletado (92/200): Bloody New Year (1987) - https://www.imdb.com/title/tt0092676
# Coletado (93/200): The Horror Show Must Go On (1987) - https://www.imdb.com/title/tt0198503
# Coletado (94/200): Silent Night, Deadly Night Part 2 (1987) - https://www.imdb.com/title/tt0093974
# Coletado (95/200): The Haunted Cop Shop (1987) - https://www.imdb.com/title/tt0093522
# Coletado (96/200): Twisted Nightmare (1987) - https://www.imdb.com/title/tt0134167
# Coletado (97/200): Creepshow 2 (1987) - https://www.imdb.com/title/tt0092796
# Coletado (98/200): Little Shop of Horrors (1987) - https://www.imdb.com/title/tt29763408
# Coletado (99/200): Contagion (1987) - https://www.imdb.com/title/tt0123733
# Coletado (100/200): Paganini Horror (1988) - https://www.imdb.com/title/tt0095812
# Coletado (101/200): Waxwork (1988) - https://www.imdb.com/title/tt0096426
# Coletado (102/200): Friday the 13th: The New Blood (1988) - https://www.imdb.com/title/tt0095179
# Coletado (103/200): The Unnamable (1988) - https://www.imdb.com/title/tt0096344
# Coletado (104/200): Curse of the Blue Lights (1988) - https://www.imdb.com/title/tt0199439
# Coletado (105/200): Ghosthouse (1988) - https://www.imdb.com/title/tt0093090
# Coletado (106/200): Evil Clutch (1988) - https://www.imdb.com/title/tt0097307
# Coletado (107/200): Dream Demon (1988) - https://www.imdb.com/title/tt0095063
# Coletado (108/200): Howling IV: The Original Nightmare (1988) - https://www.imdb.com/title/tt0095334
# Coletado (109/200): The Newlydeads (1988) - https://www.imdb.com/title/tt0093614
# Coletado (110/200): 976-EVIL (1988) - https://www.imdb.com/title/tt0094597
# Coletado (111/200): Human Kennel Horror Highway (1988) - https://www.imdb.com/title/tt11439848
# Coletado (112/200): House III: The Horror Show (1989) - https://www.imdb.com/title/tt0097527
# Coletado (113/200): Amityville Horror: The Evil Escapes (1989) - https://www.imdb.com/title/tt0096808
# Coletado (114/200): Horror Rock (1989) - https://www.imdb.com/title/tt4704830
# Coletado (115/200): Society (1989) - https://www.imdb.com/title/tt0098354
# Coletado (116/200): Houseboat Horror (1989) - https://www.imdb.com/title/tt0097529
# Coletado (117/200): Tales from the Crypt (1989) - https://www.imdb.com/title/tt0096708
# Coletado (118/200): The Bloody Video Horror That Made Me Puke on My Aunt Gertrude (1989) - https://www.imdb.com/title/tt2762474
# Coletado (119/200): A Nightmare on Elm Street: The Dream Child (1989) - https://www.imdb.com/title/tt0097981
# Coletado (120/200): Nightwish (1989) - https://www.imdb.com/title/tt0097982
# Coletado (121/200): Howling V: The Rebirth (1989) - https://www.imdb.com/title/tt0097534
# Coletado (122/200): Faces of Horror (1989) - https://www.imdb.com/title/tt0233690
# Coletado (123/200): The Sweet House of Horrors (1989) - https://www.imdb.com/title/tt0097221
# Coletado (124/200): The Late Night Horror Show with Count Norlock (1989) - https://www.imdb.com/title/tt9370052
# Coletado (125/200): Horrorama (1989) - https://www.imdb.com/title/tt1267169
# Coletado (126/200): Murder in Law (1989) - https://www.imdb.com/title/tt0100208
# Coletado (127/200): Battle Heater (1989) - https://www.imdb.com/title/tt0222798
#
# --- Coleta de Filmes Concluída: 127 de 200 filmes coletados. ---
#
# --- Análise das Sinopses ---
# Iniciando pré-processamento das sinopses com SpaCy...
# Calculando frequência das palavras nas sinopses...
#
# --- 100 Palavras Mais Frequentes nas Sinopses ---
# 'horror': 94
# 'house': 50
# 'movie': 47
# 'evil': 42
# 'new': 41
# 'group': 35
# 'night': 34
# 'town': 33
# 'professor': 32
# 'young': 30
# 'tv': 30
# 'years': 27
# 'people': 27
# 'hosted': 26
# 'father': 26
# 'soon': 25
# 'find': 25
# 'man': 25
# 'film': 23
# 'mother': 23
# 'city': 22
# 'channel': 22
# 'friends': 22
# 'killer': 22
# 'life': 22
# 'dead': 21
# 'billy': 21
# 'killed': 20
# 'family': 20
# 'local': 20
# 'murder': 20
# 'eddie': 20
# 'story': 19
# 'old': 19
# 'stop': 19
# 'death': 18
# 'mysterious': 18
# 'de': 18
# 'begins': 18
# 'finds': 17
# 'movies': 17
# 'lake': 17
# 'boy': 17
# 'killing': 17
# 'host': 17
# 'werewolf': 17
# 'brother': 16
# 'carvalho': 16
# 'rio': 16
# 'janeiro': 16
# 'brazil': 16
# 'monster': 16
# 'girl': 16
# 'woman': 16
# 'hospital': 16
# 'count': 16
# 'late': 16
# 'time': 16
# 'rock': 16
# 'little': 15
# 'gets': 15
# 'blood': 15
# 'dr': 15
# 'son': 15
# 'goes': 15
# 'students': 15
# 'store': 15
# 'plant': 15
# 'audrey': 15
# 'friend': 14
# 'murdered': 14
# 'police': 14
# 'deadly': 14
# 'high': 14
# 'santa': 14
# 'seymour': 14
# 'paul': 14
# 'book': 13
# 'mark': 13
# 'discovers': 13
# 'world': 13
# 'tom': 13
# 'later': 13
# 'children': 13
# 'help': 13
# 'remote': 13
# 'home': 13
# 'tina': 13
# 'series': 12
# 'haunted': 12
# 'student': 12
# 'owner': 12
# 'tribe': 12
# 'returns': 12
# 'daughter': 12
# 'day': 12
# 'cabin': 12
# 'small': 12
# 'college': 12
# 'mansion': 12
#
# Processo concluído!

# %%
# --- Célula Adicional: Verificação de Ocorrência de Termos Específicos ---

# Esta célula deve ser executada APÓS o script principal, na mesma sessão do Jupyter.
# As variáveis 'filmes_para_processar' e 'nlp' já devem estar definidas.

print("\n--- Verificação de Ocorrência de Termos Específicos em Sinopses ---")

# Lista de termos que você quer verificar (em minúsculas)
termos_para_verificar = ['horror'] # Adicione ou remova termos aqui

for i, filme in enumerate(filmes_para_processar):
    plot = filme.get('plot', '')
    title = filme.get('title', 'Título Desconhecido')
    imdb_link = filme.get('imdb_link', 'Link Desconhecido')

    # Processa a sinopse individualmente, igual ao processo geral
    doc_individual = nlp(plot.lower())
    
    # Extrai tokens (palavras) filtradas da sinopse individual
    palavras_na_sinopse = [
        token.text for token in doc_individual
        if not token.is_stop and not token.is_punct and token.is_alpha and len(token.text) > 1
    ]

    encontrados_no_filme = []
    
    # Verifica a presença de cada termo na sinopse processada
    for termo in termos_para_verificar:
        if termo in palavras_na_sinopse:
            count = palavras_na_sinopse.count(termo)
            encontrados_no_filme.append(f"'{termo}': {count} vez(es)")
    
    if encontrados_no_filme:
        print(f"\nFilme {i+1}: '{title}' ({filme.get('year')})")
        print(f"  Link IMDb: {imdb_link}")
        print(f"  Termos encontrados: {', '.join(encontrados_no_filme)}")
        print(f"  Trecho da Sinopse (para contexto):")
        # Mostra um trecho da sinopse original para dar contexto
        # Encontra a primeira ocorrência de um dos termos e mostra o texto ao redor
        plot_lower = plot.lower()
        context_found = False
        for termo in termos_para_verificar:
            if termo in plot_lower:
                start_index = max(0, plot_lower.find(termo) - 50) # 50 caracteres antes
                end_index = min(len(plot_lower), plot_lower.find(termo) + len(termo) + 50) # 50 caracteres depois
                context = plot[start_index:end_index]
                print(f"    ...{context}...")
                context_found = True
                break # Mostra contexto para o primeiro termo encontrado
        if not context_found: # Se nenhum termo foi encontrado, mas a lista 'encontrados_no_filme' não está vazia (algum erro lógico)
            print("    (Contexto não exibido, erro de busca de termo para contexto)")

if not filmes_para_processar:
    print("\nNenhum filme coletado no script principal para verificar.")

print("\nVerificação de termos concluída!")
